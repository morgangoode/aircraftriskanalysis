# %% [markdown]
# ## Importing Data Set on Aviation Risk

# %%
import pandas as pd

# %% [markdown]
# ## Loading and read the CSV file

# %%
df=pd.read_csv("../Phase1/data/AviationData.csv", encoding = "ISO-8859-1")
# Out:
# C:\Users\NCG\AppData\Local\Temp\ipykernel_5820\2280785669.py:1: DtypeWarning: Columns (6,7,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("../Phase1/data/AviationData.csv", encoding = "ISO-8859-1")

# %% [markdown]
# ## Using .info() and .describe() to view missing values and statistical measures

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50249 non-null  object
#  9   Airport.Name            52790 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87572 non-null  object
# ...

# %%
df.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       82805.000000          77488.000000            76379.000000
# mean            1.146585              0.647855                0.279881
# std             0.446510              5.485960                1.544084
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             8.000000            349.000000              161.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count          76956.000000     82977.000000
# mean               0.357061         5.325440
# std                2.235625        27.913634
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# ...

# %% [markdown]
# ## Using .head(10) to view the first 10 incidents as a dataframe

# %%
df.head(10)
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
# 5  20170710X52551           Accident      NYC79AA106  1979-09-17
# 6  20001218X45446           Accident      CHI81LA106  1981-08-01
# 7  20020909X01562           Accident      SEA82DA022  1982-01-01
# 8  20020909X01561           Accident      NYC82DA015  1982-01-01
# 9  20020909X01560           Accident      MIA82DA029  1982-01-01
#
#            Location        Country   Latitude  Longitude Airport.Code  \
# 0   MOOSE CREEK, ID  United States        NaN        NaN          NaN
# 1    BRIDGEPORT, CA  United States        NaN        NaN          NaN
# ...

# %% [markdown]
# ## Viewing Missing Data in "Weather.Condition"

# %%
df['Weather.Condition'].isna().value_counts()
# Out:
# False    84397
# True      4492
# Name: Weather.Condition, dtype: int64

# %% [markdown]
# 4492 missing weather conditions in our data set

# %% [markdown]
# ## Filtering for Weather Condition and Injury Types

# %%
df[['Weather.Condition', 'Total.Fatal.Injuries', 'Total.Serious.Injuries', 'Total.Minor.Injuries']]
# Out:
#       Weather.Condition  Total.Fatal.Injuries  Total.Serious.Injuries  \
# 0                   UNK                   2.0                     0.0
# 1                   UNK                   4.0                     0.0
# 2                   IMC                   3.0                     NaN
# 3                   IMC                   2.0                     0.0
# 4                   VMC                   1.0                     2.0
# ...                 ...                   ...                     ...
# 88884               NaN                   0.0                     1.0
# 88885               NaN                   0.0                     0.0
# 88886               VMC                   0.0                     0.0
# 88887               NaN                   0.0                     0.0
# 88888               NaN                   0.0                     1.0
#
#        Total.Minor.Injuries
# 0                       0.0
# 1                       0.0
# 2                       NaN
# ...
