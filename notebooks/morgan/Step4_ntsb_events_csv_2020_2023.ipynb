# %% [markdown]
# #Reading in data directly from NTSB to compare to our Kaggle dataset.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e8bda936-c12e-48c8-922d-4934bcadb6d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8bda936-c12e-48c8-922d-4934bcadb6d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %% [markdown]
# First up, exploring the `events` table from NTSB.

# %%
df_events = pd.read_csv('events.csv')

# %%
df_events.head(3)
# Out:
#             ev_id     ntsb_no ev_type            ev_date ev_dow  ev_time  \
# 0  20200725X60143  CEN20LA306     ACC  07/25/20 00:00:00     Sa      NaN
# 1  20210404102861  ERA21LA171     ACC  04/03/21 00:00:00     Sa      NaN
# 2  20210615103270  CEN21FA270     ACC  06/15/21 00:00:00     Tu      NaN
#
#   ev_tmzn    ev_city ev_state ev_country  ...  ntsb_notf_from  ntsb_notf_date  \
# 0     UTC      Grant       NE        USA  ...             NaN             NaN
# 1     UTC    Palmyra       PA        USA  ...             NaN             NaN
# 2     UTC  Paragould       AR        USA  ...             NaN             NaN
#
#    ntsb_notf_tm fiche_number          lchg_date lchg_userid wx_cond_basic  \
# 0           NaN          NaN  05/03/23 20:32:28        frik           VMC
# 1           NaN          NaN  05/03/23 20:32:30        coln           VMC
# 2           NaN          NaN  05/03/23 20:32:30       broda           VMC
#
#   faa_dist_office dec_latitude dec_longitude
# ...

# %%
df_events.tail(3)
# Out:
#              ev_id     ntsb_no ev_type            ev_date ev_dow  ev_time  \
# 60  20230504107811  CEN23LA170     ACC  04/30/23 00:00:00     Su      NaN
# 61  20230504107812  CEN23LA171     ACC  05/03/23 00:00:00     We      NaN
# 62  20230504107814  ERA23LA217     ACC  05/04/23 00:00:00     Th      NaN
#
#    ev_tmzn           ev_city ev_state ev_country  ...  ntsb_notf_from  \
# 60     UTC            Palmer       TX        USA  ...             NaN
# 61     UTC            Gretna       NE        USA  ...             NaN
# 62     UTC  Defuniak Springs       FL        USA  ...             NaN
#
#     ntsb_notf_date  ntsb_notf_tm fiche_number          lchg_date lchg_userid  \
# 60             NaN           NaN          NaN  05/05/23 16:33:58        fina
# 61             NaN           NaN          NaN  05/04/23 19:04:48        broz
# 62             NaN           NaN          NaN  05/04/23 23:31:25        schl
#
#    wx_cond_basic faa_dist_office dec_latitude dec_longitude
# ...

# %%
df_events.describe
# Out:
# <bound method NDFrame.describe of              ev_id     ntsb_no ev_type            ev_date ev_dow  ev_time  \
# 0   20200725X60143  CEN20LA306     ACC  07/25/20 00:00:00     Sa      NaN
# 1   20210404102861  ERA21LA171     ACC  04/03/21 00:00:00     Sa      NaN
# 2   20210615103270  CEN21FA270     ACC  06/15/21 00:00:00     Tu      NaN
# 3   20211007104067  CEN22LA009     ACC  10/06/21 00:00:00     We      NaN
# 4   20211025104158  ANC22LA004     ACC  10/24/21 00:00:00     Su      NaN
# ..             ...         ...     ...                ...    ...      ...
# 58  20230503107307  ERA23LA215     ACC  04/24/23 00:00:00     Mo      NaN
# 59  20230504107809  ERA23LA216     ACC  04/27/23 00:00:00     Th      NaN
# 60  20230504107811  CEN23LA170     ACC  04/30/23 00:00:00     Su      NaN
# 61  20230504107812  CEN23LA171     ACC  05/03/23 00:00:00     We      NaN
# 62  20230504107814  ERA23LA217     ACC  05/04/23 00:00:00     Th      NaN
#
# ...

# %%
# counting the NaN values
events_nan_count_cols = df_events.isna().sum() 
events_nan_count_cols
# Out:
# ev_id               0
# ntsb_no             0
# ev_type             0
# ev_date             0
# ev_dow              0
#                    ..
# lchg_userid         0
# wx_cond_basic      12
# faa_dist_office    63
# dec_latitude        0
# dec_longitude       0
# Length: 73, dtype: int64

# %%
df_events.columns
# Out:
# Index(['ev_id', 'ntsb_no', 'ev_type', 'ev_date', 'ev_dow', 'ev_time',
#        'ev_tmzn', 'ev_city', 'ev_state', 'ev_country', 'ev_site_zipcode',
#        'ev_year', 'ev_month', 'mid_air', 'on_ground_collision', 'latitude',
#        'longitude', 'latlong_acq', 'apt_name', 'ev_nr_apt_id', 'ev_nr_apt_loc',
#        'apt_dist', 'apt_dir', 'apt_elev', 'wx_brief_comp', 'wx_src_iic',
#        'wx_obs_time', 'wx_obs_dir', 'wx_obs_fac_id', 'wx_obs_elev',
#        'wx_obs_dist', 'wx_obs_tmzn', 'light_cond', 'sky_cond_nonceil',
#        'sky_nonceil_ht', 'sky_ceil_ht', 'sky_cond_ceil', 'vis_rvr', 'vis_rvv',
#        'vis_sm', 'wx_temp', 'wx_dew_pt', 'wind_dir_deg', 'wind_dir_ind',
#        'wind_vel_kts', 'wind_vel_ind', 'gust_ind', 'gust_kts', 'altimeter',
#        'wx_dens_alt', 'wx_int_precip', 'metar', 'ev_highest_injury',
#        'inj_f_grnd', 'inj_m_grnd', 'inj_s_grnd', 'inj_tot_f', 'inj_tot_m',
#        'inj_tot_n', 'inj_tot_s', 'inj_tot_t', 'invest_agy', 'ntsb_docket',
# ...

# %%
# Event date is cleanly formatted, includes timecode
# We should convert to datetime object and drop the timecode
df_events['ev_date'].values
# Out:
# array(['07/25/20 00:00:00', '04/03/21 00:00:00', '06/15/21 00:00:00',
#        '10/06/21 00:00:00', '10/24/21 00:00:00', '10/28/21 00:00:00',
#        '11/12/21 00:00:00', '11/22/21 00:00:00', '12/02/21 00:00:00',
#        '12/22/21 00:00:00', '04/07/22 00:00:00', '06/13/22 00:00:00',
#        '06/19/22 00:00:00', '07/05/22 00:00:00', '07/04/22 00:00:00',
#        '06/25/22 00:00:00', '07/17/22 00:00:00', '07/10/22 00:00:00',
#        '07/23/22 00:00:00', '07/27/22 00:00:00', '07/30/22 00:00:00',
#        '08/03/22 00:00:00', '08/04/22 00:00:00', '07/27/22 00:00:00',
#        '08/06/22 00:00:00', '07/04/22 00:00:00', '07/16/22 00:00:00',
#        '08/04/22 00:00:00', '08/15/22 00:00:00', '07/16/22 00:00:00',
#        '12/07/22 00:00:00', '12/10/22 00:00:00', '12/06/22 00:00:00',
#        '03/03/23 00:00:00', '03/14/23 00:00:00', '03/24/23 00:00:00',
#        '03/21/23 00:00:00', '03/29/23 00:00:00', '04/08/23 00:00:00',
# ...

# %%
# this column seems unneccessary 
df_events['ev_year'].values
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])

# %%
# checking out the datatypes from the events table
df_events.dtypes
# Out:
# ev_id               object
# ntsb_no             object
# ev_type             object
# ev_date             object
# ev_dow              object
#                     ...
# lchg_userid         object
# wx_cond_basic       object
# faa_dist_office    float64
# dec_latitude       float64
# dec_longitude      float64
# Length: 73, dtype: object

# %%
# The state column from NTSB's events table is much cleaner than our dataset
state_list = df_events['ev_state'].tolist() 
unique_state_list = set(state_list)
unique_state_list
# Out:
# {'AK',
#  'AL',
#  'AR',
#  'AZ',
#  'CA',
#  'CT',
#  'FL',
#  'GA',
#  'KY',
#  'LA',
#  'MA',
#  'MT',
#  'NC',
#  'NE',
#  'NM',
#  'NY',
#  'OF',
#  'OH',
#  'OK',
#  'PA',
#  'RI',
#  'TN',
#  'TX',
#  'UT',
#  'VA',
#  'WA',
#  'WV'}

# %%
# curious! Is it possible that only 27 states were involved in accidents/incidents during the time period?
# This dataset starts in 2020, 72 years after the Kaggle dataset.
# Need to import more tables 
len(unique_state_list)
# Out:
# 27
