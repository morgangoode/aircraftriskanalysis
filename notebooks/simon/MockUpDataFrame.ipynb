# %% [markdown]
# # SIMON'S MOCK UP
#
# ### FIRST I IMPORT LIBRARIES

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ### THEN I IMPORT AND READ ORIGINAL AVIATION DATA CSV FILE.
#
# ### THEN I LIST COLUMNS

# %%
df = pd.read_csv('data/AviationData.csv', encoding = "ISO-8859-1")

df.columns.tolist()
# Out:
# C:\Users\simon\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (6,7,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ['Event.Id',
#  'Investigation.Type',
#  'Accident.Number',
#  'Event.Date',
#  'Location',
#  'Country',
#  'Latitude',
#  'Longitude',
#  'Airport.Code',
#  'Airport.Name',
#  'Injury.Severity',
#  'Aircraft.damage',
#  'Aircraft.Category',
#  'Registration.Number',
#  'Make',
#  'Model',
#  'Amateur.Built',
#  'Number.of.Engines',
#  'Engine.Type',
#  'FAR.Description',
#  'Schedule',
#  'Purpose.of.flight',
#  'Air.carrier',
#  'Total.Fatal.Injuries',
#  'Total.Serious.Injuries',
#  'Total.Minor.Injuries',
#  'Total.Uninjured',
#  'Weather.Condition',
#  'Broad.phase.of.flight',
#  'Report.Status',
#  'Publication.Date']

# %% [markdown]
# ## .SHAPE, .HEAD(), .INFO(), .DESCRIBE()

# %%
df.shape
# Out:
# (88889, 31)

# %%
# Show all columns by disabling truncation
pd.set_option('display.max_columns', None)

# Disable column-wise line wrapping
pd.set_option('display.expand_frame_repr', False)

df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date         Location        Country Latitude Longitude Airport.Code Airport.Name Injury.Severity Aircraft.damage Aircraft.Category Registration.Number      Make     Model Amateur.Built  Number.of.Engines    Engine.Type FAR.Description Schedule Purpose.of.flight Air.carrier  Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured Weather.Condition Broad.phase.of.flight   Report.Status Publication.Date
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24  MOOSE CREEK, ID  United States      NaN       NaN          NaN          NaN        Fatal(2)       Destroyed               NaN              NC6404   Stinson     108-3            No                1.0  Reciprocating             NaN      NaN          Personal         NaN                   2.0                     0.0                   0.0              0.0               UNK                Cruise  Probable Cause              NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50249 non-null  object
#  9   Airport.Name            52790 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87572 non-null  object
# ...

# %%
df.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured
# count       82805.000000          77488.000000            76379.000000          76956.000000     82977.000000
# mean            1.146585              0.647855                0.279881              0.357061         5.325440
# std             0.446510              5.485960                1.544084              2.235625        27.913634
# min             0.000000              0.000000                0.000000              0.000000         0.000000
# 25%             1.000000              0.000000                0.000000              0.000000         0.000000
# 50%             1.000000              0.000000                0.000000              0.000000         1.000000
# 75%             1.000000              0.000000                0.000000              0.000000         2.000000
# ...

# %% [markdown]
# ### HERE I RETRIEVED ALL INPUTS FROM EACH COLUMN BUT ONLY IF NUMBER OF UNIQUE INPUTS FOR COLUMN <= 30 (JUST FOR FUNSIES)

# %%
max_unique_threshold = 30

for column in df.columns:
    unique_values = df[column].unique()
    if len(unique_values) <= max_unique_threshold: 
        print(f'Column: {column}')
        print('Unique Values:')
        for value in unique_values:
              print(value)
        print()
# Out:
# Column: Investigation.Type
# Unique Values:
# Accident
# Incident
#
# Column: Aircraft.damage
# Unique Values:
# Destroyed
# Substantial
# Minor
# nan
# Unknown
#
# Column: Aircraft.Category
# Unique Values:
# nan
# Airplane
# Helicopter
# Glider
# Balloon
# Gyrocraft
# Ultralight
# Unknown
# Blimp
# Powered-Lift
# Weight-Shift
# Powered Parachute
# Rocket
# WSFT
# UNK
# ULTR
#
# Column: Amateur.Built
# Unique Values:
# No
# Yes
# nan
#
# Column: Number.of.Engines
# Unique Values:
# 1.0
# nan
# 2.0
# 0.0
# 3.0
# 4.0
# 8.0
# 6.0
#
# Column: Engine.Type
# Unique Values:
# Reciprocating
# nan
# Turbo Fan
# Turbo Shaft
# Unknown
# Turbo Prop
# Turbo Jet
# None
# Electric
# Hybrid Rocket
# Geared Turbofan
# LR
# NONE
# UNK
#
# Column: Schedule
# Unique Values:
# nan
# SCHD
# NSCH
# UNK
#
# Column: Purpose.of.flight
# Unique Values:
# Personal
# nan
# Business
# Instructional
# Unknown
# Ferry
# Executive/corporate
# Aerial Observation
# Aerial Application
# Public Aircraft
# Skydiving
# ...

# %% [markdown]
# ### ----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### HERE I SORTED THE EVENT DATES SO I CAN SEE THE EARLIEST LISTING OF A CRASH

# %%
event_date = 'Event.Date'

earliest_elements = df.sort_values(event_date)[event_date].head(5)

earliest_elements
# Out:
# 0    1948-10-24
# 1    1962-07-19
# 2    1974-08-30
# 3    1977-06-19
# 4    1979-08-02
# Name: Event.Date, dtype: object

# %%
index_of_interest = 0

row_of_interest = df.loc[index_of_interest]

print("Row of interest:")
print(row_of_interest)
# Out:
# Row of interest:
# Event.Id                   20001218X45444
# Investigation.Type               Accident
# Accident.Number                SEA87LA080
# Event.Date                     1948-10-24
# Location                  MOOSE CREEK, ID
# Country                     United States
# Latitude                              NaN
# Longitude                             NaN
# Airport.Code                          NaN
# Airport.Name                          NaN
# Injury.Severity                  Fatal(2)
# Aircraft.damage                 Destroyed
# Aircraft.Category                     NaN
# Registration.Number                NC6404
# Make                              Stinson
# Model                               108-3
# Amateur.Built                          No
# Number.of.Engines                       1
# Engine.Type                 Reciprocating
# FAR.Description                       NaN
# Schedule                              NaN
# Purpose.of.flight                Personal
# ...

# %% [markdown]
# ### DEFINED FUNCTION THAT GIVES ME UNIQUE INPUTS FOR MY DESIRED COLUMN

# %%
#CODE REFACTORING so that I wouldn't have to copy and paste the same code block over and over;
#instead I can just call on 'print_unique_inputs'"

def print_unique_inputs(df, column_name):

    unique_inputs = df[column_name].unique()
    num_unique_inputs = len(unique_inputs)

    print("Unique inputs for the '{}' column:".format(column_name))
    print(unique_inputs)

    print("Number of unique inputs for the '{}' column: {}".format(column_name, num_unique_inputs))
    
    return unique_inputs

# %% [markdown]
# #### For example, the Make column

# %%
target_column = 'Make'
unique_inputs = print_unique_inputs(df, target_column)
# Out:
# Unique inputs for the 'Make' column:
# ['Stinson' 'Piper' 'Cessna' ... 'JAMES R DERNOVSEK' 'ORLICAN S R O'
#  'ROYSE RALPH L']
# Number of unique inputs for the 'Make' column: 8238

# %% [markdown]
# ### FROM OUTSIDE RESEARCH, FOUND OUT THAT MOST COMMONLY USED COMMERCIAL PLANE TODAY IS THE 'BOEING 737 NEXT GENERATION', WHICH MADE ITS DEBUT IN 1997.

# %%
#looking to see if 'Boeing' exists in the 'Make' column

target_make = 'Boeing'

if target_make in unique_inputs:
    print("'{}' is within the unique inputs for the '{}' column.".format(target_make, target_column))
else:
    print("'{}' is not found in the unique inputs for the '{}' column.".format(target_make, target_column))
# Out:
# 'Boeing' is within the unique inputs for the 'Make' column.

# %% [markdown]
# ### NOW I REMOVE ALL ENTRIES PRIOR TO 1997.

# %%
# convert to datetime just in case
df['Event.Date'] = pd.to_datetime(df['Event.Date'])

df = df[df['Event.Date'].dt.year >= 1997]

# reset the index to avoid complications
df = df.reset_index(drop = True)

df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number Event.Date           Location        Country Latitude Longitude Airport.Code          Airport.Name Injury.Severity Aircraft.damage Aircraft.Category Registration.Number           Make      Model Amateur.Built  Number.of.Engines    Engine.Type FAR.Description Schedule Purpose.of.flight      Air.carrier  Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured Weather.Condition Broad.phase.of.flight   Report.Status Publication.Date
# ...

# %% [markdown]
# ### NOW I DELVE INTO 'Amateur.Built' COLUMN AND SUBSEQUENTLY REMOVE ALL AMATEUR-BUILT MACHINES

# %%
target_column = 'Amateur.Built'
unique_inputs = print_unique_inputs(df, target_column)
# Out:
# Unique inputs for the 'Amateur.Built' column:
# ['No' 'Yes' nan]
# Number of unique inputs for the 'Amateur.Built' column: 3

# %%
df = df[df['Amateur.Built'] != 'Yes']

df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number Event.Date           Location        Country Latitude Longitude Airport.Code          Airport.Name Injury.Severity Aircraft.damage Aircraft.Category Registration.Number           Make      Model Amateur.Built  Number.of.Engines    Engine.Type FAR.Description Schedule Purpose.of.flight      Air.carrier  Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured Weather.Condition Broad.phase.of.flight   Report.Status Publication.Date
# ...

# %% [markdown]
# ### ENGINE TIMEEEEEE! IDENTIFY UNIQUE ENGINE TYPES AND DROP ALL THE ONES THAT AREN'T USED BY COMMERCIAL AIRPLANES (involes outside research)

# %%
target_column = 'Engine.Type'
unique_inputs = print_unique_inputs(df, target_column)
# Out:
# Unique inputs for the 'Engine.Type' column:
# ['Reciprocating' 'Turbo Fan' 'Turbo Prop' 'Turbo Shaft' 'Turbo Jet'
#  'Unknown' nan 'None' 'Electric' 'Hybrid Rocket' 'Geared Turbofan' 'LR'
#  'UNK' 'NONE']
# Number of unique inputs for the 'Engine.Type' column: 14

# %%
target_column = 'Number.of.Engines'
unique_inputs = print_unique_inputs(df, target_column)
# Out:
# Unique inputs for the 'Number.of.Engines' column:
# [ 1.  2. nan  3.  4.  0.  8.  6.]
# Number of unique inputs for the 'Number.of.Engines' column: 8

# %% [markdown]
# ### CREATE A SEPARATE DF WITH ENGINES FOR AIRPLANES FILTERED

# %%
inputs_to_drop = ['Turbo Shaft', 'Reciprocating', 'Electric', 'Hybrid Rocket']

# drop rows with the specified inputs in 'Engine.Type' column
engine_filtered_df = df[~df['Engine.Type'].isin(inputs_to_drop)].copy()

engine_filtered_df.head()
# Out:
#           Event.Id Investigation.Type Accident.Number Event.Date             Location        Country Latitude Longitude Airport.Code              Airport.Name Injury.Severity Aircraft.damage Aircraft.Category Registration.Number           Make     Model Amateur.Built  Number.of.Engines Engine.Type FAR.Description Schedule Purpose.of.flight                              Air.carrier  Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured Weather.Condition Broad.phase.of.flight   Report.Status Publication.Date
# ...

# %% [markdown]
# ### ----------------------------------------------------------------------------------------------------------

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42441 entries, 0 to 47796
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                42441 non-null  object
#  1   Investigation.Type      42441 non-null  object
#  2   Accident.Number         42441 non-null  object
#  3   Event.Date              42441 non-null  datetime64[ns]
#  4   Location                42408 non-null  object
#  5   Country                 42402 non-null  object
#  6   Latitude                30191 non-null  object
#  7   Longitude               30185 non-null  object
#  8   Airport.Code            25198 non-null  object
#  9   Airport.Name            25627 non-null  object
#  10  Injury.Severity         41442 non-null  object
#  11  Aircraft.damage         40194 non-null  object
#  12  Aircraft.Category       25266 non-null  object
#  13  Registration.Number     41226 non-null  object
# ...

# %%
target_column = 'Aircraft.damage'
unique_inputs = print_unique_inputs(df, target_column)
# Out:
# Unique inputs for the 'Aircraft.damage' column:
# ['Destroyed' 'Substantial' 'Minor' nan 'Unknown']
# Number of unique inputs for the 'Aircraft.damage' column: 5

# %% [markdown]
# ### TIME TO MAKE FRENQUENCY TABLE BETWEEN ENGINE TYPES AND AIRCRAFT DAMAGE

# %%
engine_aircraftDmg_dropna = df.dropna(subset = ['Engine.Type', 'Aircraft.damage'])

frequency_table = pd.crosstab(engine_aircraftDmg_dropna['Engine.Type'], engine_aircraftDmg_dropna['Aircraft.damage'])

print(frequency_table)
# Out:
# Aircraft.damage  Destroyed  Minor  Substantial  Unknown
# Engine.Type
# Electric                 2      0            8        0
# Geared Turbofan          0      1            0        0
# Hybrid Rocket            1      0            0        0
# LR                       0      0            1        0
# NONE                     0      0            1        0
# None                     1      1           13        0
# Reciprocating         3851    297        24577        5
# Turbo Fan              118    368          543        0
# Turbo Jet               69     59          143        0
# Turbo Prop             439    125         1443        0
# Turbo Shaft            378     59         1604        0
# UNK                      0      0            1        0
# Unknown                222     54          283        0

# %%
import matplotlib.pyplot as plt

# %%
#transpose frequency table (swap x and y values in plot)
#frequency_table = frequency_table.transpose() <-- uncomment this to swap values every time you run this cell.

#figure size
plt.figure(figsize=(10, 6))

#plot frequency table
frequency_table.plot(kind = 'bar', stacked = True)

#labeling 
plt.xlabel('Engine Type')
plt.ylabel('Frequency')
plt.title('Frequency of Aircraft Damage by Engine Type')

#display plot
plt.show()
